# %% [markdown]
# #딥러닝으로 분류하기

# %% [markdown]
# #데이터셋 확인

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/winequality-white.csv", sep=';')

df.dropna()
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %% [markdown]
# #결측치 확인

# %%
df['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %% [markdown]
# #데이터 나누기

# %%
#입력과 출력 나누기
X = df.drop(columns=['quality'])
Y = df['quality']

X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol
# 0         8.8
# 1         9.5
# 2        10.1
# 3         9.9
# 4         9.9
# ...       ...
# 4893     11.2
# 4894      9.6
# 4895      9.4
# 4896     12.8
# 4897     11.8
#
# [4898 rows x 11 columns]

# %%
Y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %% [markdown]
# #X를 스케일링 하기

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# #결측치를 0부터 인코딩하기

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
encoder = LabelEncoder()

# Y 데이터를 인코딩하여 Y_encoded 변수에 저장
Y_encoded = encoder.fit_transform(Y)

# 변환된 라벨을 Y에 할당하여 업데이트
Y = Y_encoded

# 업데이트된 Y의 상위 5개 값 확인
print("업데이트된 Y 데이터의 상위 5개:\n", Y[:5])

# 업데이트된 Y의 고유한 값과 개수 확인
print("\n업데이트된 Y의 고유한 값들:", pd.Series(Y).unique())
print("\n업데이트된 Y의 값별 개수:\n", pd.Series(Y).value_counts().sort_index())
# Out:
# 업데이트된 Y 데이터의 상위 5개:
#  [3 3 3 3 3]
#
# 업데이트된 Y의 고유한 값들: [3 2 4 5 1 0 6]
#
# 업데이트된 Y의 값별 개수:
#  0      20
# 1     163
# 2    1457
# 3    2198
# 4     880
# 5     175
# 6       5
# Name: count, dtype: int64

# %%
Y
# Out:
# array([3, 3, 3, ..., 3, 4, 3])

# %% [markdown]
# #one-hot encoding 하기

# %%
# one-hot encoding 하기
# Y_encoded는 LabelEncoder를 통해 1차원으로 변환된 데이터입니다.
Y = pd.get_dummies(Y_encoded).values

Y
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ..., False, False, False]])

# %% [markdown]
# #X를 NUMPY로 변경

# %%
X = X.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2258008927.py in <cell line: 0>()
# ----> 1 X = X.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %% [markdown]
# #train과 Test로 나누기

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

X
# Out:
# array([[ 7.  ,  0.27,  0.36, ...,  3.  ,  0.45,  8.8 ],
#        [ 6.3 ,  0.3 ,  0.34, ...,  3.3 ,  0.49,  9.5 ],
#        [ 8.1 ,  0.28,  0.4 , ...,  3.26,  0.44, 10.1 ],
#        ...,
#        [ 6.5 ,  0.24,  0.19, ...,  2.99,  0.46,  9.4 ],
#        [ 5.5 ,  0.29,  0.3 , ...,  3.34,  0.38, 12.8 ],
#        [ 6.  ,  0.21,  0.38, ...,  3.26,  0.32, 11.8 ]])

# %%
Y
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ..., False, False, False]])

# %% [markdown]
# #모델 학습

# %%
from tensorflow.keras import layers, models
model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)),
    layers.Dropout(0.3),
    layers.Dense(32, activation="relu"),
    layers.Dense(Y.shape[1], activation="softmax")   # 클래스 수 맞춤
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",   # one-hot이면 categorical_crossentropy
    metrics=["accuracy"]
)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2613 - loss: 14.2362 - val_accuracy: 0.4668 - val_loss: 2.3438
# Epoch 2/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4755 - loss: 1.1497 - val_accuracy: 0.5077 - val_loss: 1.1235
# Epoch 31/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4873 - loss: 1.1764 - val_accuracy: 0.4949 - val_loss: 1.1136
# Epoch 32/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4695 - loss: 1.1818 - val_accuracy: 0.5000 - val_loss: 1.1218
# Epoch 33/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4695 - loss: 1.1568 - val_accuracy: 0.4821 - val_loss: 1.1137
# Epoch 34/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4813 - loss: 1.1695 - val_accuracy: 0.4758 - val_loss: 1.1148
# Epoch 35/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4826 - loss: 1.1845 - val_accuracy: 0.4949 - val_loss: 1.1172
# Epoch 36/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4762 - loss: 1.1806 - val_accuracy: 0.5128 - val_loss: 1.1098
# Epoch 37/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4809 - loss: 1.1486 - val_accuracy: 0.4974 - val_loss: 1.1351
# Epoch 38/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4996 - loss: 1.1089 - val_accuracy: 0.4911 - val_loss: 1.1238
# Epoch 39/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5043 - loss: 1.1528 - val_accuracy: 0.5153 - val_loss: 1.1173
# Epoch 40/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4665 - loss: 1.1378 - val_accuracy: 0.4923 - val_loss: 1.1234
# Epoch 41/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4689 - loss: 1.1597 - val_accuracy: 0.4936 - val_loss: 1.1142
# Epoch 42/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4935 - loss: 1.1213 - val_accuracy: 0.4987 - val_loss: 1.1126
# Epoch 43/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4765 - loss: 1.1379 - val_accuracy: 0.4783 - val_loss: 1.1087
# Epoch 44/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4963 - loss: 1.1163 - val_accuracy: 0.5077 - val_loss: 1.1066
# Epoch 45/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4919 - loss: 1.1165 - val_accuracy: 0.4885 - val_loss: 1.1223
# Epoch 46/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4843 - loss: 1.1318 - val_accuracy: 0.5102 - val_loss: 1.1039
# Epoch 47/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4998 - loss: 1.1201 - val_accuracy: 0.5166 - val_loss: 1.0941
# Epoch 48/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4851 - loss: 1.1217 - val_accuracy: 0.5089 - val_loss: 1.1027
# Epoch 49/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4993 - loss: 1.1175 - val_accuracy: 0.5102 - val_loss: 1.1005
# Epoch 50/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5125 - loss: 1.0844 - val_accuracy: 0.5038 - val_loss: 1.1064

# %% [markdown]
# #결과값

# %%
import numpy as np

y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']


y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

import matplotlib.pyplot as plt
import seaborn as sns

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc =  history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       0.00      0.00      0.00        51
#            2       0.44      0.42      0.43       295
#            3       0.45      0.76      0.56       409
#            4       0.50      0.02      0.04       183
#            5       0.00      0.00      0.00        33
#
#     accuracy                           0.45       980
#    macro avg       0.23      0.20      0.17       980
# weighted avg       0.41      0.45      0.37       980
#
# [[  0   1   4   4   0   0]
#  [  0   0  36  15   0   0]
#  [  0   0 125 170   0   0]
#  [  0   1  97 309   1   1]
#  [  0   0  19 159   4   1]
#  [  0   0   1  29   3   0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
